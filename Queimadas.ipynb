# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
total = pd.read_csv('total.csv', sep=';')
total
# Out:
#      Ano   Total
# 0   2003  176958
# 1   2004  212859
# 2   2005  250018
# 3   2006  141251
# 4   2007  189977
# 5   2008   90618
# 6   2009   50901
# 7   2010  228667
# 8   2011   59329
# 9   2012  105106
# 10  2013   56947
# 11  2014   79550
# 12  2015   78570
# 13  2016  131131
# 14  2017   99901
# 15  2018   74785

# %%
total_ate_agosto = 142192

# %%
media_por_anos = []

for i in range(len(total)):
    media_por_anos.append(total['Total'][-1*(i+1):].mean())
    
media_por_anos = list(reversed(media_por_anos))

# %%
fig = plt.figure(figsize=(20,10),facecolor='white')
ax = plt.axes()


font = {'family': 'serif',
        'weight': 'normal',
        'size': 20,
        }

x = list(range(16,0,-1))
ax.plot( media_por_anos);

ax.plot([total_ate_agosto]*(len(x)))

locs, labels = plt.xticks()
plt.xticks(list(range(0,16)), x, fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('Quantidade de anos considerada', fontdict=font)
plt.title('Média do total de queimadas até dia 31/08 de cada ano', fontdict=font)


#plt.savefig('queimadas.jpg')
# Out:
# Text(0.5,1,'Média do total de queimadas até dia 31/08 de cada ano')
